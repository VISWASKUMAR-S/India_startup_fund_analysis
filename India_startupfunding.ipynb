# %% [markdown]
# <a href="https://colab.research.google.com/github/Svk396/India_startup_fund_analysis/blob/main/India_startupfunding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import libiaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/startup_funding.csv')
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
df.head(5)
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.tail(5)
# Out:
#       Sr No Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# 3039   3040      29/01/2015        Printvenue               NaN         NaN
# 3040   3041      29/01/2015          Graphene               NaN         NaN
# 3041   3042      30/01/2015    Mad Street Den               NaN         NaN
# 3042   3043      30/01/2015         Simplotel               NaN         NaN
# 3043   3044      31/01/2015  couponmachine.in               NaN         NaN
#
#      City  Location                     Investors Name InvestmentnType  \
# 3039            NaN        Asia Pacific Internet Group  Private Equity
# 3040            NaN                     KARSEMVEN Fund  Private Equity
# 3041            NaN     Exfinity Fund, GrowX Ventures.  Private Equity
# 3042            NaN                         MakeMyTrip  Private Equity
# 3043            NaN  UK based Group of Angel Investors    Seed Funding
#
#      Amount in USD                            Remarks
# ...

# %%
#CHECK SHAPE FO THE DATA ROWS AND COLUMNS
df.shape
# Out:
# (3044, 10)

# %% [markdown]
# The data set has 3044 rows and 10 coulmns

# %%
#DATSET inforamtion
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
#calclulate the null values in each column
df.isna().sum()
# Out:
# Sr No                   0
# Date dd/mm/yyyy         0
# Startup Name            0
# Industry Vertical     171
# SubVertical           936
# City  Location        180
# Investors Name         24
# InvestmentnType         4
# Amount in USD         960
# Remarks              2625
# dtype: int64

# %%
#calculate the percentage of null values in the data set for each column
(df.isna().sum()/df.shape[0])*100
# Out:
# Sr No                 0.000000
# Date dd/mm/yyyy       0.000000
# Startup Name          0.000000
# Industry Vertical     5.617608
# SubVertical          30.749014
# City  Location        5.913272
# Investors Name        0.788436
# InvestmentnType       0.131406
# Amount in USD        31.537451
# Remarks              86.235217
# dtype: float64

# %% [markdown]
# Remarks column has the highest percentage of null values , we can drop the column in further analysis.We have to replace the null values in other columns with apporatite values like mean or mode in the columns

# %%
#Check for any duplicate values present in the data set
df.duplicated().value_counts()
# Out:
# False    3044
# Name: count, dtype: int64

# %% [markdown]
# No duplicate values are present in the dataset

# %%
df.drop(columns=['Remarks'],inplace=True)

# %%
df.set_index('Sr No',inplace=True)

# %%
df
# Out:
#       Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# Sr No
# 1          09/01/2020                        BYJU’S               E-Tech
# 2          13/01/2020                        Shuttl       Transportation
# 3          09/01/2020                     Mamaearth           E-commerce
# 4          02/01/2020  https://www.wealthbucket.in/              FinTech
# 5          02/01/2020                        Fashor  Fashion and Apparel
# ...               ...                           ...                  ...
# 3040       29/01/2015                    Printvenue                  NaN
# 3041       29/01/2015                      Graphene                  NaN
# 3042       30/01/2015                Mad Street Den                  NaN
# 3043       30/01/2015                     Simplotel                  NaN
# 3044       31/01/2015              couponmachine.in                  NaN
#
#                                  SubVertical City  Location  \
# Sr No
# ...

# %%
#CHANGE THE COLUMNS TO APPROITE NAME
df.rename(columns={
     'Date dd/mm/yyyy': 'date',
    'Startup Name': 'startup',
    'Industry Vertical': 'vertical',
    'SubVertical': 'subvertical',
    'City  Location': 'city',
    'Investors Name': 'investors',
    'InvestmentnType': 'invesment_type',
    'Amount in USD': 'amount_in_INR_CR'
},inplace=True)

# %%
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
# Fill missing values in the 'vertical' column with the most frequent value
df['vertical'] = df['vertical'].fillna(df['vertical'].mode()[0])

# Fill missing values in the 'subvertical' column with the most frequent value
df['subvertical'] = df['subvertical'].fillna(df['subvertical'].mode()[0])

# Fill missing values in the 'city' column with the most frequent value
df['city'] = df['city'].fillna(df['city'].mode()[0])

# Fill missing values in the 'investors' column with the most frequent value
df['investors'] = df['investors'].fillna(df['investors'].mode()[0])

# Fill missing values in the 'inv_type' column with the most frequent value
df['invesment_type'] = df['invesment_type'].fillna(df['invesment_type'].mode()[0])

# %%
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue    Consumer Internet
# 3041   29/01/2015                      Graphene    Consumer Internet
# 3042   30/01/2015                Mad Street Den    Consumer Internet
# 3043   30/01/2015                     Simplotel    Consumer Internet
# 3044   31/01/2015              couponmachine.in    Consumer Internet
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
#check cuurency value nullvalues
df['amount_in_INR_CR'].unique()
# Out:
# array(['20,00,00,000', '80,48,394', '1,83,58,860', '30,00,000',
#        '18,00,000', '90,00,000', '15,00,00,000', '60,00,000',
#        '7,00,00,000', '5,00,00,000', '2,00,00,000', '1,20,00,000',
#        '3,00,00,000', '59,00,000', '20,00,000', '23,10,00,000',
#        '4,86,000', '15,00,000', 'undisclosed', '2,60,00,000',
#        '1,74,11,265', '13,00,000', '13,50,00,000', '3,00,000',
#        '22,00,00,000', '1,58,00,000', '28,30,00,000', '1,00,00,00,000',
#        '4,50,00,000', '58,50,00,000', 'unknown', '45,00,000', '33,00,000',
#        '50,00,000', '1,80,00,000', '10,00,000', '1,00,00,000',
#        '45,00,00,000', '16,00,000', '14,00,00,000', '3,80,80,000',
#        '12,50,00,000', '1,10,00,000', '5,10,00,000', '3,70,00,000',
#        '5,00,000', '11,00,00,000', '1,50,00,000', '65,90,000',
#        'Undisclosed', '3,90,00,00,000', '1,90,00,000', '25,00,000',
#        '1,45,000', '6,00,00,000', '1,60,00,000', '57,50,000', '3,19,605',
# ...

# %%
# Fill missing values in the ''amount_in_INR_CR'' column with '0'
df['amount_in_INR_CR'] = df['amount_in_INR_CR'].fillna('0')

# Remove commas from the 'amount(CR)' column
df['amount_in_INR_CR'] = df['amount_in_INR_CR'].str.replace(",", "")

# Replace strings 'undisclosed', 'unknown', and 'Undisclosed' with '0'
df['amount_in_INR_CR'] = df['amount_in_INR_CR'].str.replace("undisclosed", "0")
df['amount_in_INR_CR'] = df['amount_in_INR_CR'].str.replace("unknown", "0")
df['amount_in_INR_CR'] = df['amount_in_INR_CR'].str.replace("Undisclosed", "0")

# %%
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue    Consumer Internet
# 3041   29/01/2015                      Graphene    Consumer Internet
# 3042   30/01/2015                Mad Street Den    Consumer Internet
# 3043   30/01/2015                     Simplotel    Consumer Internet
# 3044   31/01/2015              couponmachine.in    Consumer Internet
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df.rename(columns={'amount_in_INR_CR':'amount(CR)'},inplace=True)

# %%
# Filter the DataFrame to only include rows where the 'amount(CR)' column contains digits
df = df[df['amount(CR)'].str.isdigit()]

# Convert the 'amount(CR)' column to a float data type
df['amount(CR)'] = df['amount(CR)'].astype('float')

def To_inr(dollar):
  """
  Converts a dollar amount to Indian rupees (INR) in crores.

  Args:
      dollar: The dollar amount.

  Returns:
      The INR amount in crores.
  """

  inr = round(dollar * 82.5 ,3)
  return inr / 10000000


df['amount(CR)']=df['amount(CR)'].apply(To_inr)
df.rename(columns={'amount(CR)':'amount_in_INR_CR'},inplace=True)
# Out:
# <ipython-input-324-92b9d9b5980b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount(CR)'] = df['amount(CR)'].astype('float')
# <ipython-input-324-92b9d9b5980b>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount(CR)']=df['amount(CR)'].apply(To_inr)
# <ipython-input-324-92b9d9b5980b>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue    Consumer Internet
# 3041   29/01/2015                      Graphene    Consumer Internet
# 3042   30/01/2015                Mad Street Den    Consumer Internet
# 3043   30/01/2015                     Simplotel    Consumer Internet
# 3044   31/01/2015              couponmachine.in    Consumer Internet
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
# Replace incorrect date formats in the 'date' column of dataframe 'df'

# Replace "05/072018" with "05/07/2018"
df['date'] = df['date'].replace("05/072018", "05/07/2018")

# Replace "01/07/015" with "01/07/2015"
df['date'] = df['date'].replace("01/07/015", "01/07/2015")

# Replace "22/01//2015" with "22/01/2015"
df['date'] = df['date'].replace("22/01//2015", "22/01/2015")

# Replace "01/07/015" with "01/07/2015"
df['date'] = df['date'].replace("01/07/015", "01/07/2015")
# Out:
# <ipython-input-326-9c629d0c1fd0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].replace("05/072018", "05/07/2018")
# <ipython-input-326-9c629d0c1fd0>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].replace("01/07/015", "01/07/2015")
# <ipython-input-326-9c629d0c1fd0>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Convert the 'date' column in dataframe 'df' to datetime format, handling errors with 'coerce'

df['date'] = pd.to_datetime(df['date'], errors='coerce')
# Out:
# <ipython-input-327-dd7db83f19d6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              1285 non-null   datetime64[ns]
#  1   startup           3029 non-null   object
#  2   vertical          3029 non-null   object
#  3   subvertical       3029 non-null   object
#  4   city              3029 non-null   object
#  5   investors         3029 non-null   object
#  6   invesment_type    3029 non-null   object
#  7   amount_in_INR_CR  3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
df['startup'].unique().tolist()
# Out:
# ['BYJU’S',
#  'Shuttl',
#  'Mamaearth',
#  'https://www.wealthbucket.in/',
#  'Fashor',
#  'Pando',
#  'Zomato',
#  'Ecozen',
#  'CarDekho',
#  'Dhruva Space',
#  'Rivigo',
#  'Healthians',
#  'Licious',
#  'InCred',
#  'Trell',
#  'Rein Games',
#  'Lenskart.com',
#  'Freshworks',
#  'Misters',
#  'Sunstone Eduversity Pvt. Ltd',
#  'Burger Singh',
#  'Ninjacart',
#  'Aye Finance',
#  'SuperGaming',
#  'Clumio',
#  'eBikeGo',
#  'Digital Mall Asia',
#  'Medikabazaar',
#  'Vogo Automotive',
#  'Furtados School of Music',
#  'Paytm',
#  'Dunzo',
#  'Udaan',
#  'The Man Company',
#  'FPL Technologies',
#  'Cashflo',
#  'Digital F5',
#  '3rdFlix',
#  '75F',
#  'Myelin Foundry',
#  'Atomberg Technology',
#  'GOQii',
#  'Vyapar App',
#  'Progcap',
#  'MyPetrolPump',
#  'Alteria Capital',
#  'Pine Labs',
#  'Meesho',
#  'Cars24',
#  'Uniphore',
#  'Zendrive',
#  'Lo! Foods',
#  'Tala',
#  'INDwealth',
#  'HungerBox',
#  'AdmitKard',
#  'Mishry Reviews',
#  'Grofers',
#  'Rapido Bike Taxi',
# ...

# %%
# Filter rows where startup name starts with "Ola" but doesn't end with it
ola_mask = df['startup'].str.startswith('Ola') & ~df['startup'].str.endswith('Ola')
# Update startup name for filtered rows
df.loc[ola_mask, 'startup'] = 'Ola'

# Verify the changes
df[df['startup'].str.startswith('Ola')]
# If you want to update the DataFrame in-place, you can directly use:
df.loc[ola_mask, 'startup'] = 'Ola'

# %%
# Filter rows where startup name starts with "Ola" but doesn't end with it
rapido_mask = df['startup'].str.startswith('Rapido') & ~df['startup'].str.endswith('Rapido')

# Update startup name for filtered rows
df.loc[rapido_mask, 'startup'] = 'Rapido'

# If you want to update the DataFrame in-place, you can directly use:
df.loc[rapido_mask, 'startup'] = 'Rapido'

# %%
# Verify the changes
df[df['startup'].str.startswith('Rapido')]
# Out:
#       date startup           vertical                            subvertical  \
# Sr No
# 61     NaT  Rapido     Transportation                              Bike Taxi
# 504    NaT  Rapido         Technology  Bike and Taxi pooling online platform
# 622    NaT  Rapido  Consumer Internet             Bike Aggregator Mobile App
# 1781   NaT  Rapido  Consumer Internet                    Bike Aggregator App
#
#             city                                          investors  \
# Sr No
# 61     Bengaluru                                 Westbridge Capital
# 504    Hyderabad                     Skycatcher Fund, Aravind Sanka
# 622    Bangalore                  Battery Road Digital Holdings LLC
# 1781   Bangalore  Pawan Munjal, AdvantEdge Partners, Astarc Vent...
#
#            invesment_type  amount_in_INR_CR
# Sr No
# 61               Series B      32175.000000
# 504    Seed/Angel Funding          2.716147
# 622          Seed Funding          3.481500
# ...

# %%
df['startup'].replace({
    "Byju\xe2\x80\x99s":"BYJU'S",
    "BYJU\xe2\x80\x99s":"BYJU'S",
    "BYJU\\\'S":"BYJU'S"
      # Add more variations if needed
},inplace=True)
# Out:
# <ipython-input-333-7392d77dfd3e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['startup'].replace({

# %%
df['startup']=df['startup'].str.replace("https://www.wealthbucket.in/","wealthbucket")
# Out:
# <ipython-input-334-43591a46519b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['startup']=df['startup'].str.replace("https://www.wealthbucket.in/","wealthbucket")

# %%
df.to_csv("startup_cleaned.csv",index=False)

# %%
sorted(df['startup'].unique().tolist())
# Out:
# ['"BYJU\\\\\'S"',
#  '#Fame',
#  '121Policy',
#  '19th mile',
#  '1Crowd',
#  '1mg',
#  '1mg (Healthkartplus)',
#  '20Dresses',
#  '33Coupons',
#  '360Ride',
#  '3Dexter',
#  '3HCare',
#  '3rdFlix',
#  '48East',
#  '4tigo',
#  '5th Vital',
#  '6Degree',
#  '75F',
#  '91SpringBoard',
#  '99Games',
#  '99PerHour',
#  '9Stacks',
#  'A&R Bon Vivants',
#  'ABI Health',
#  'AEON Learning',
#  'AHA Taxis',
#  'AYE Finance',
#  'AadharAPI.com',
#  'Aadyah',
#  'Aahaa',
#  'Aahaa Stores',
#  'Aarav UAV',
#  'Aasaanjobs',
#  'Aashiyaan',
#  'Aavishkaar-Intellecap Group',
#  'AbeRuk',
#  'Abhibus',
#  'Absentia',
#  'Absentia VR',
#  'Ace Turtle',
#  'Ace2three',
#  'Acko',
#  'ActOnMagic',
#  'Actionable Analytics',
#  'Active AI',
#  'Active.ai',
#  'Actofit',
#  'Ad2pro',
#  'AdPushUp',
#  'AdStringO',
#  'AdUrCup',
#  'AdWyze',
#  'Address Health',
#  'AdmitKard',
#  'Advanced Structures India',
#  'Advantage Club',
#  'Advenio',
#  'Adytude',
#  'Aequm',
#  'AerMed',
#  'Affimity',
# ...

# %%
df['investors'].tolist()
# Out:
# ['Tiger Global Management',
#  'Susquehanna Growth Equity',
#  'Sequoia Capital India',
#  'Vinod Khatumal',
#  'Sprout Venture Partners',
#  'Chiratae Ventures',
#  'Ant Financial',
#  'Sathguru Catalyzer Advisors',
#  'Ping An Global Voyager Fund',
#  'Mumbai Angels, Ravikanth Reddy',
#  'SAIF Partners, Spring Canter Investment Ltd.',
#  'Paytm, NPTK, Sabre Partners and Neoplux',
#  'Vertex Growth Fund',
#  'Undisclosed Investors',
#  'Ruizheng Investment',
#  'Manipal Education and Medical Group (MEMG)',
#  'SoftBank Vision Fund',
#  'Sequoia, CapitalG, Accel',
#  'Sauce.vc, Rainforest Ventures',
#  'Prime Venture Partners, LetsVenture, PS1 Venture and GlobalLogic co-founder Rajul Garg',
#  'RB Investments',
#  'DG Daiwa Ventures, DG Incubation',
#  'Trifecta Capital Advisors',
#  'FinTech',
#  'Dream Incubator',
#  'Altimeter Capital, Sutter Hill Ventures',
#  'Startup Buddy',
#  'Amour Infrastructure',
#  'Ackermans & van Haaren, HealthQuad, Rebright Partners, Toppan Printing',
# ...

# %%
sorted(set(df['investors'].str.split(",").sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
# ...

# %%
df['amount_in_INR_CR'].describe()
# Out:
# count     3029.000000
# mean       103.594832
# std        829.745897
# min          0.000000
# 25%          0.000000
# 50%          4.125000
# 75%         33.000000
# max      32175.000000
# Name: amount_in_INR_CR, dtype: float64

# %%
#df['date'].fillna(0,inplace=True)
#df['date']

# %%
#df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
# Extract Year as an integer, handling NaT values
df['year'] = df['date'].dt.year.dropna().astype(int)

# Extract Month as an integer
df['month'] = df['date'].dt.month

# Extract Quarter as an integer
df['quarter'] = df['date'].dt.quarter
# Out:
# <ipython-input-342-2c7594e9d4e5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['date'].dt.year.dropna().astype(int)
# <ipython-input-342-2c7594e9d4e5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['date'].dt.month
# <ipython-input-342-2c7594e9d4e5>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 3029 entries, 1 to 3044
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 1285 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 47.3 KB

# %%
# Extract Year as an integer
df['year'] = df['date'].dt.year

# Extract Month as an integer
df['month'] = df['date'].dt.month

# Extract Quarter as an integer
df['quarter'] = df['date'].dt.quarter
# Out:
# <ipython-input-345-9e4754b63826>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['date'].dt.year
# <ipython-input-345-9e4754b63826>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['date'].dt.month
# <ipython-input-345-9e4754b63826>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['year'].isnull().value_counts()
# Out:
# year
# True     1744
# False    1285
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

totalno_of_startup_city = df.groupby('city')['startup'].nunique().sort_values(ascending=False)
ax = totalno_of_startup_city.head(5).plot(kind='bar') # Use .plot() instead of .plt()

# Adding title and data labels to the plot
plt.title('Top 5 Cities by Number of Startups')
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show() # Display the plot

# %%
No_of_startup_by_year = df.groupby('year')['startup'].nunique()
ax = No_of_startup_by_year.plot(kind='bar')
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.title('No.of.startup.by.year')
plt.show()

# %%
import matplotlib.pyplot as plt

No_of_startup_by_vertical = df.groupby('vertical')['startup'].nunique().sort_values(ascending=False)
top_5_verticals = No_of_startup_by_vertical.head(5)

# Creating a pie chart with data labels
plt.pie(top_5_verticals, labels=top_5_verticals.index, autopct='%1.1f%%', startangle=90)
plt.title('No. of Startups by Vertical (Top 5)')
plt.axis('equal')
plt.show()

# %%
# Sector analysis by sum
sector_sums = df.groupby('vertical')['amount_in_INR_CR'].sum().sort_values(ascending=False)
# Select top sectors based on sum
top_sectors_sum = sector_sums.head(5)

plt.pie(top_sectors_sum, labels=top_sectors_sum.index,autopct= '%1.1f%%',startangle=90)
plt.title('Topsectors_by_amount(top5)')
plt.axis('equal')
plt.show()

# %%
top_sectors_sum
# Out:
# vertical
# Consumer Internet    61750.388807
# eCommerce            41270.897250
# Transportation       32312.217250
# Technology           18395.090423
# Finance              16264.363500
# Name: amount_in_INR_CR, dtype: float64

# %%
subvertical_sums = df.groupby('subvertical')['amount_in_INR_CR'].sum().sort_values(ascending=False)
subvertical_sums
# Out:
# subvertical
# Online Lending Platform               73070.970786
# Bike Taxi                             32175.000000
# Online Marketplace                    21851.775000
# ECommerce Marketplace                 14025.000000
# Mobile Wallet & ECommerce platform    12045.000000
#                                           ...
# Online Insurance platform                 0.000000
# Online Interior Design platform           0.000000
# Contactless Payment Solution              0.000000
# Online Job Board                          0.000000
# Co-Working Spaces aggregator              0.000000
# Name: amount_in_INR_CR, Length: 1938, dtype: float64

# %%
#plot pie chart
top_5_subvertical = subvertical_sums.head(5)
plt.pie(top_5_subvertical, labels=top_5_subvertical.index,autopct= '%1.1f%%',startangle=90)
plt.title('Top5_subvertical_by_amount')
# Out:
# Text(0.5, 1.0, 'Top5_subvertical_by_amount')

# %%
funding_types = df['invesment_type'].value_counts().head(5)
fig8, ax8 = plt.subplots(figsize=(6,4))
ax8.bar(funding_types.index,funding_types.values)
funding_types.plot(kind='bar')
plt.xlabel('Funding Type')
plt.ylabel('Count')
plt.title('Type of Funding')
# Out:
# Text(0.5, 1.0, 'Type of Funding')

# %%
df
# Out:
#             date           startup             vertical  \
# Sr No
# 1     2020-09-01            BYJU’S               E-Tech
# 2            NaT            Shuttl       Transportation
# 3     2020-09-01         Mamaearth           E-commerce
# 4     2020-02-01      wealthbucket              FinTech
# 5     2020-02-01            Fashor  Fashion and Apparel
# ...          ...               ...                  ...
# 3040         NaT        Printvenue    Consumer Internet
# 3041         NaT          Graphene    Consumer Internet
# 3042         NaT    Mad Street Den    Consumer Internet
# 3043         NaT         Simplotel    Consumer Internet
# 3044         NaT  couponmachine.in    Consumer Internet
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-374-88b96acb2292> in <cell line: 1>()
# ----> 1 df['month'] =df['month'].dt.month.astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
startup_by_month=df.groupby(['year','month'])['startup'].count().reset_index()
startup_by_month.rename(columns={'startup':'startup_count'},inplace=True)
startup_by_month
# Out:
#       year  month  startup_count
# 0   2015.0    1.0             37
# 1   2015.0    2.0             29
# 2   2015.0    3.0             41
# 3   2015.0    4.0             22
# 4   2015.0    5.0             32
# ..     ...    ...            ...
# 57  2019.0   11.0              5
# 58  2019.0   12.0              5
# 59  2020.0    2.0              2
# 60  2020.0    9.0              2
# 61  2020.0   10.0              1
#
# [62 rows x 3 columns]

# %%
# Assuming 'startup_by_month' DataFrame is already available as in the preceding code

# Create a new column for month-year labels
startup_by_month['month_year'] = startup_by_month['month'].astype(str) + '-' + startup_by_month['year'].astype(str)

# Plot the bar chart
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
plt.bar(startup_by_month['month_year'], startup_by_month['startup_count'])
plt.xlabel('Month-Year')
plt.ylabel('Count of Startups')
plt.title('Number of Startups Funded Each Month')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
temp_df=df.groupby(['year','month'])['amount_in_INR_CR'].sum().reset_index()


temp_df['x_val']=temp_df['year'].astype('str')+ '-' +temp_df['month'].astype('str')
temp_df
# Out:
#       year  month  amount_in_INR_CR        x_val
# 0   2015.0    1.0       5279.835000   2015.0-1.0
# 1   2015.0    2.0       1862.194950   2015.0-2.0
# 2   2015.0    3.0       2536.322250   2015.0-3.0
# 3   2015.0    4.0       1944.896250   2015.0-4.0
# 4   2015.0    5.0       1086.937500   2015.0-5.0
# ..     ...    ...               ...          ...
# 57  2019.0   11.0       1153.350000  2019.0-11.0
# 58  2019.0   12.0       1233.375000  2019.0-12.0
# 59  2020.0    2.0         39.600000   2020.0-2.0
# 60  2020.0    9.0       1801.460595   2020.0-9.0
# 61  2020.0   10.0       1237.500000  2020.0-10.0
#
# [62 rows x 4 columns]

# %%
df.groupby(['year','month'])['amount_in_INR_CR'].sum().reset_index()
# Out:
#       year  month  amount_in_INR_CR
# 0   2015.0    1.0       5279.835000
# 1   2015.0    2.0       1862.194950
# 2   2015.0    3.0       2536.322250
# 3   2015.0    4.0       1944.896250
# 4   2015.0    5.0       1086.937500
# ..     ...    ...               ...
# 57  2019.0   11.0       1153.350000
# 58  2019.0   12.0       1233.375000
# 59  2020.0    2.0         39.600000
# 60  2020.0    9.0       1801.460595
# 61  2020.0   10.0       1237.500000
#
# [62 rows x 3 columns]

# %%
# Assuming 'temp_df' DataFrame is already available as in the preceding code

plt.figure(figsize=(12, 6))
plt.plot(temp_df['x_val'], temp_df['amount_in_INR_CR'])
plt.xlabel('Month-Year')
plt.ylabel('Total Investment (INR CR)')
plt.title('Month over Month Investment in Rupees')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
quater_wise_amount=df.groupby(['year','quarter'])['amount_in_INR_CR'].sum().reset_index()
quater_wise_amount
# Out:
#       year  quarter  amount_in_INR_CR
# 0   2015.0      1.0       9678.352200
# 1   2015.0      2.0       6470.887500
# 2   2015.0      3.0       9244.882086
# 3   2015.0      4.0       4205.561250
# 4   2016.0      1.0       1540.984500
# 5   2016.0      2.0       2434.096500
# 6   2016.0      3.0       3906.210000
# 7   2016.0      4.0       4724.420250
# 8   2017.0      1.0       7722.082500
# 9   2017.0      2.0       3469.694250
# 10  2017.0      3.0       4775.149500
# 11  2017.0      4.0      22828.715250
# 12  2018.0      1.0       7581.977659
# 13  2018.0      2.0       4269.936000
# 14  2018.0      3.0       4044.489405
# 15  2018.0      4.0       3139.628984
# 16  2019.0      1.0      10121.966250
# 17  2019.0      2.0       7297.690950
# 18  2019.0      3.0       1904.954741
# 19  2019.0      4.0       4034.102985
# 20  2020.0      1.0         39.600000
# 21  2020.0      3.0       1801.460595
# 22  2020.0      4.0       1237.500000

# %%
# Assuming 'quater_wise_amount' is your DataFrame with 'year', 'quarter', and 'amount_in_INR_CR' columns

# Group the data by year and quarter and sum the amount
quater_wise_amount = df.groupby(['year', 'quarter'])['amount_in_INR_CR'].sum().reset_index()

# Create labels for the x-axis by combining year and quarter
quater_wise_amount['x_val'] = quater_wise_amount['year'].astype(str) + '-Q' + quater_wise_amount['quarter'].astype(str)

# Create the bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.bar(quater_wise_amount['x_val'], quater_wise_amount['amount_in_INR_CR'])
plt.xlabel('Year-Quarter')
plt.ylabel('Total Amount (INR CR)')
plt.title('Quarter-wise Investment Amount')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %%
# Add Top Startups year-wise analysis

top_startups_year_wise = df.groupby(['year', 'startup'])['amount_in_INR_CR'].sum().reset_index()
top_startups_year_wise = top_startups_year_wise.sort_values(by=['year', 'amount_in_INR_CR'], ascending=[True, False])

# Select top 5 startups for each year
top_5_startups_year_wise = top_startups_year_wise.groupby('year').head(5)

fig10, ax10 = plt.subplots(figsize=(12, 8))  # Increase the figure size
for year, data in top_5_startups_year_wise.groupby('year'):
    ax10.barh(data['startup'], data['amount_in_INR_CR'], label=str(year))  # Use barh for horizontal bar chart

ax10.legend()
plt.xlabel('Investment Amount (CR)')
plt.ylabel('Startup')
plt.title('Top Startup Year Wise')
plt.tight_layout()  # Adjust layout to prevent overlap

# %%
# Add Top Investors analysis
top_investors_year_wise = df.groupby(['year', 'investors'])['amount_in_INR_CR'].sum().reset_index()
top_investors_year_wise = top_investors_year_wise.sort_values(by=['year', 'amount_in_INR_CR'], ascending=[True, False])

# Select top 5 investors for each year
top_5_investors_year_wise = top_investors_year_wise.groupby('year').head(5)

fig11, ax11 = plt.subplots(figsize=(12, 8))  # Increase the figure size
for year, data in top_5_investors_year_wise.groupby('year'):
    ax11.barh(data['investors'], data['amount_in_INR_CR'], label=str(year))  # Use barh for horizontal bar chart

ax11.legend()
plt.xlabel('Investment Amount (CR)')
plt.ylabel('Investor')
plt.title('Top Investor Year Wise')
plt.tight_layout()  # Adjust layout to prevent overlap
# Out:
# <ipython-input-370-8eadd529ef47>:16: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()  # Adjust layout to prevent overlap
